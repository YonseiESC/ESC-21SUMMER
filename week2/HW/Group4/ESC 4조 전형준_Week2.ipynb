# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# 단계별로 생성된 모델들 중 예측변수(또는 설명변수)가 4개인 모델에서, 새롭게 선택된 변수의 이름은 무엇인가요?
#
# 4개인 모델에서 새로 선택된 변수의 이름은 dis

# %% [markdown]
# 그 변수의 추정된 계수의 값과 해당 모델의 결정계수 R^2는 무엇인가요?
#
# 변수가 4개일 때 dis의 추정된 계수의 값은 -0.5519263
#
# 모델의 결정계수 R^2의 값은 0.6903077

# %% [markdown]
# ![3.jpg](attachment:3.jpg)
